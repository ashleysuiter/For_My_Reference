# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Time Series: Moving Statistics

# %%
import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Load the Unemployment data set. Perform any necessary cleaning and preprocess the data by creating a `datetime` index.

# %%
unemp = pd.read_csv('../assets/data/unemployment.csv')
unemp.head()
# Out:
#   Quarter  \
# 0  1948Q1
# 1  1948Q2
# 2  1948Q3
# 3  1948Q4
# 4  1949Q1
#
#   Seasonally adjusted quarterly U.S. unemployment rates from 1948 to 1993
# 0                                             3.733%
# 1                                             3.667%
# 2                                             3.767%
# 3                                             3.833%
# 4                                             4.667%

# %%
unemp.tail()
# Out:
#                                                Quarter  \
# 170                                             1990Q3
# 171                                             1990Q4
# 172                                             1991Q1
# 173                                             1991Q2
# 174  Seasonally adjusted quarterly U.S. unemploymen...
#
#     Seasonally adjusted quarterly U.S. unemployment rates from 1948 to 1993
# 170                                               5.6%
# 171                                               5.9%
# 172                                               6.5%
# 173                                             6.833%
# 174                                                NaN

# %%
# Drop messed up last row
# /scrub/
unemp.drop(174, inplace=True)
unemp.tail()
# Out:
#     Quarter  \
# 169  1990Q2
# 170  1990Q3
# 171  1990Q4
# 172  1991Q1
# 173  1991Q2
#
#     Seasonally adjusted quarterly U.S. unemployment rates from 1948 to 1993
# 169                                             5.333%
# 170                                               5.6%
# 171                                               5.9%
# 172                                               6.5%
# 173                                             6.833%

# %%
# Check for additional nulls
# /scrub/
unemp.isnull().sum()
# Out:
# Quarter                                                                    0
# Seasonally adjusted quarterly U.S. unemployment rates from 1948 to 1993    0
# dtype: int64

# %%
# Simplify column names
# /scrub/
unemp.columns = ['year_quarter', 'unemployment_rate']
unemp.head()
# Out:
#   year_quarter unemployment_rate
# 0       1948Q1            3.733%
# 1       1948Q2            3.667%
# 2       1948Q3            3.767%
# 3       1948Q4            3.833%
# 4       1949Q1            4.667%

# %%
# Convert unemployment rate to float
# /scrub/
unemp.loc[:, 'unemployment_rate'] = (
    unemp.loc[:, 'unemployment_rate'].str.replace('%','').apply(float)
)
unemp.head()
# Out:
#   year_quarter  unemployment_rate
# 0       1948Q1              3.733
# 1       1948Q2              3.667
# 2       1948Q3              3.767
# 3       1948Q4              3.833
# 4       1949Q1              4.667

# %%
# Check data types
# /scrub/
unemp.dtypes
# Out:
# year_quarter          object
# unemployment_rate    float64
# dtype: object

# %%
# Converting to datetime using .dt.to_period('Q')
# /scrub/
unemp.loc[:, 'year_quarter'] = pd.to_datetime(unemp.loc[:, 'year_quarter']).dt.to_period('Q')
unemp.set_index('year_quarter', inplace=True)
unemp.head()
# Out:
#               unemployment_rate
# year_quarter
# 1948Q1                    3.733
# 1948Q2                    3.667
# 1948Q3                    3.767
# 1948Q4                    3.833
# 1949Q1                    4.667

# %%
# Confirm that objects in index are correct datetimes
# /scrub/
unemp.index.month
# Out:
# Int64Index([ 3,  6,  9, 12,  3,  6,  9, 12,  3,  6,
#             ...
#              3,  6,  9, 12,  3,  6,  9, 12,  3,  6],
#            dtype='int64', name='year_quarter', length=174)

# %%
# Plot the unemployment rate
# /scrub/
ax = unemp.loc[:, 'unemployment_rate'].plot()

# %% [markdown]
# To make the data a bit easier to work with, we will average over the four quarters within each year to get an estimated yearly average unemployment rate.

# %%
# Calculate yearly means
# /scrub/
unemp_rate = unemp.loc[:, 'unemployment_rate'].resample('A').mean()
unemp_rate.head()
# Out:
# year_quarter
# 1948    3.75000
# 1949    6.05025
# 1950    5.20825
# 1951    3.28350
# 1952    3.02500
# Freq: A-DEC, Name: unemployment_rate, dtype: float64

# %% [markdown]
# ## Rolling Statistics

# %% [markdown]
# Rolling means are used to smooth out noise in time series data and highlight overall trends.

# %% [markdown]
# A **simple rolling mean** with **window size** $n$ is the average of the $n$ previous values.

# %%
# Extract three-year simple rolling means
# /scrub/
three_year_rolling_mean = unemp_rate.rolling(window=3, center=False).mean()

# %% [markdown]
# **Exercise (2 mins, post immediately).**
#
# - Why are the first two values null?

# %% [markdown]
# /scrub/
#
# There are not enough previous values to calculate the rolling mean.

# %% [markdown]
# - How is a rolling mean different from mean resampling?

# %% [markdown]
# /scrub/
#
# Mean resampling reduces the number of rows in the data set by dividing the points in the data set into non-overlapping windows and replacing the values in each one with a single number, their average.
#
# A rolling mean keeps the same number of rows by replacing the value in each row with the average of that value and some number of preceding values.

# %% [markdown]
# $\blacksquare$

# %%
# Plot the yearly mean and three-year rolling mean together
# /scrub/
ax = three_year_rolling_mean.plot(figsize=(14,7))
unemp_rate.plot(ax=ax);

# %% [markdown]
# **Exercise (9 mins., pair programming)**

# %% [markdown]
# - Why does the rolling mean appear to lag behind the original series?

# %% [markdown]
# /scrub/
#
# It is including previous values in the average.

# %% [markdown]
# - Calculate the simple rolling mean with `window=5` and `window=15`. Plot both together with the original data.

# %%
# /scrub/

five_year_rolling_mean = unemp_rate.rolling(window=5, center=False).mean()
fifteen_year_rolling_mean = unemp_rate.rolling(window=15, center=False).mean()

# %%
# /scrub/

ax = unemp_rate.plot(figsize=(14,7), label='yearly mean')
three_year_rolling_mean.plot(label='3-year rolling mean of yearly mean', ax=ax)
five_year_rolling_mean.plot(label='5-year rolling mean of yearly mean', ax=ax)
fifteen_year_rolling_mean.plot(label='10-year rolling mean of yearly mean', ax=ax)
ax.legend();

# %% [markdown]
# - Recreate the plot above but with the rolling **medians** (of the annual means) instead of rolling means.

# %%
# /scrub/

three_year_rolling_median = unemp_rate.rolling(window=3, center=False).median()
five_year_rolling_median = unemp_rate.rolling(window=5, center=False).median()
ten_year_rolling_median = unemp_rate.rolling(window=10, center=False).median()

# %%
# /scrub/

ax = unemp_rate.plot(figsize=(14,7), label='yearly mean')
three_year_rolling_median.plot(label='3-year rolling median of yearly mean', ax=ax)
five_year_rolling_median.plot(label='5-year rolling median of yearly mean', ax=ax)
ten_year_rolling_median.plot(label='10-year rolling median of yearly mean', ax=ax)
ax.legend();

# %% [markdown]
# - Why might you want to use a rolling median instead of a rolling mean or vice versa?

# %% [markdown]
# /scrub/
#
# Medians are less sensitive to extreme values. If extreme values are noise that you want to smooth away, use a median. If they are real phenomena that you want to preserve, use a mean.

# %% [markdown]
# $\blacksquare$

# %% [markdown]
# A **centered rolling mean** with window size $n$ is the average of the $n$ values centered on the current time step.

# %%
# Extract three-year centered rolling means
# /scrub/
three_year_centered_rolling_mean = unemp_rate.rolling(window=3, center=True).mean()

# %%
# Plot the yearly mean, three-year simple rolling mean, and three year centered rolling mean
# /scrub/

ax = unemp_rate.plot(figsize=(14,7), label='yearly mean')
three_year_rolling_mean.plot(label='simple rolling mean', ax=ax)
three_year_centered_rolling_mean.plot(label='centered rolling mean', ax=ax)
ax.legend();

# %% [markdown]
# **Exercise (2 mins, post immediately).** What differences do you notice between the simple rolling mean and the centered rolling mean? Can you think of any advantages for the simple rolling mean?

# %% [markdown]
# /scrub/
#
# - The centered rolling mean does not show lag.
# - The centered rolling mean is null in the first and last positions, whereas the simple rolling mean is null in the first two positions.
#
# One advantage of the simple rolling mean is that it can be calculated in real time.

# %% [markdown]
# In practice, simple rolling statistics are generally used for forecasting while centered rolling statistics are used for visualization for human understanding.

# %% [markdown]
# $\blacksquare$

# %% [markdown]
# A **weighted rolling mean** treats some values as more important than others.
#
# The most common kind of weighted rolling mean is an **exponentially weighted moving average**, in which weights decay exponentially as you go back in time.
#
# The weight placed on an observation $s$ time steps in the past in an exponentially weighted moving average is proportional to $(1-\alpha)^s$ for some **decay rate** alpha. For instance, with $\alpha=.1$, the exponentially weighted moving average of $x$ at time $t$ would be proportional to the following sum:
#
# $$EMA_t \propto x_t + .9*x_{t-1} + .9^2*x_{t-2} + .9^3*x_{t-2} + \ldots$$
#
# The weights have to sum to 1, so to replace the proportionality with equality you would have to divide by the sum of the weights:
#
# $$EMA_t = \frac{x_t + .9*x_{t-1} + .9^2*x_{t-2} + .9^3*x_{t-2} + \ldots}{1 + .9 + .9^2 + \ldots}$$

# %%
# Plot weights in an exponentially weighted moving average over 20 items
num_items = 19
alpha = .1

x = range(num_items)
y = alpha * np.array([(1-alpha)**num for num in range(num_items)])
y /= sum(y)

ax = plt.bar(x, y);

# %% [markdown]
# **Implications:**
#
# - The greater the decay rate $\alpha$ is (between zero and one), the more weight the moving average places on the most recent observations. (Change alpha in the plot above to illustrate this fact.)
# - A single observation continues to influence an exponentially weighted rolling mean forever (but less and less and less...), unlike an unweighted rolling mean in which it eventually falls outside the window.
# - The standard exponentially weighted moving average lags behind the time series.

# %% [markdown]
# Sometimes the weight is described in terms of **span** or **half-life**. We will use span:
#
# $$span = 2/\alpha - 1$$
#
# An exponentially weighted moving average with span $n$ is commonly called e.g. a "$n$-day" exponentially weighted moving average (for daily data); about 86% of the weight falls on the time periods within the span.

# %%
# Calculate 10-year exponentially weighted moving average of unemployment
# /scrub/
ten_year_ewma = unemp_rate.ewm(span=10).mean()
ten_year_ewma
# Out:
# year_quarter
# 1948    3.750000
# 1949    5.015137
# 1950    5.092767
# 1951    4.496694
# 1952    4.074211
# 1953    3.775721
# 1954    4.213311
# 1955    4.248162
# 1956    4.221312
# 1957    4.237789
# 1958    4.769745
# 1959    4.905659
# 1960    5.030455
# 1961    5.351871
# 1962    5.392918
# 1963    5.440061
# 1964    5.387122
# 1965    5.222940
# 1966    4.956846
# 1967    4.750324
# 1968    4.530330
# 1969    4.339185
# 1970    4.457504
# 1971    4.731037
# 1972    4.890130
# 1973    4.884302
# 1974    5.022588
# 1975    5.652631
# 1976    6.025988
# 1977    6.212626
# 1978    6.186005
# 1979    6.124859
# 1980    6.316048
# 1981    6.552751
# 1982    7.126990
# 1983    7.576956
# 1984    7.564457
# 1985    7.496613
# 1986    7.406284
# 1987    7.182341
# 1988    6.874879
# 1989    6.582428
# 1990    6.391634
# 1991    6.441617
# Freq: A-DEC, Name: unemployment_rate, dtype: float64

# %%
# Plot the 10-year exponentially weighted moving average of unemployment with the yearly average
# /scrub/
ax = unemp_rate.plot(figsize=(14, 7), label='yearly mean')
ten_year_ewma.plot(label='5-year EWMA of yearly mean', ax=ax)
ax.legend();

# %% [markdown]
# ## Expanding Statistics

# %% [markdown]
# The **expanding mean** at a given time is the mean of all values up to that time.

# %%
# Calculate the expanding mean of unemployment
# /scrub/
expanding_mean = unemp_rate.expanding().mean()
expanding_mean.head()
# Out:
# year_quarter
# 1948    3.750000
# 1949    4.900125
# 1950    5.002833
# 1951    4.573000
# 1952    4.263400
# Freq: A-DEC, Name: unemployment_rate, dtype: float64

# %%
# Plot the expanding mean against the yearly mean
# /scrub/

ax = unemp_rate.plot(figsize=(14, 7), label='yearly mean')
expanding_mean.plot(ax=ax, label='expanding mean of yearly mean')
ax.legend();

# %% [markdown]
# ## Differencing

# %% [markdown]
# We are often interested in the **change** in a time series, as in this example:
#
# ![](../assets/images/jobs_change.png)
#
# [Source](https://fivethirtyeight.com/features/the-u-s-job-market-is-on-a-historic-growth-streak/)

# %% [markdown]
# There's a Pandas method for that: `.diff`

# %%
# Diff the unemployment rate
# /scrub/
unemp.loc[:, 'unemp_diff'] = unemp.loc[:, 'unemployment_rate'].diff()

# %%
# Plot unemployment rate and its differences in vertically arranged subplots
# /scrub/
fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(14, 7))

unemp.loc[:, 'unemployment_rate'].plot(ax=ax0)
unemp.loc[:, 'unemp_diff'].plot(ax=ax1);

# %% [markdown]
# Differencing can be used to **detrend** a time series:

# %%
x = range(200)
y = x + 10*np.random.randn(200)
diff = pd.Series(y).diff()

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, figsize=(14, 7))
ax0.plot(x, y)
ax1.plot(x, diff);

# %% [markdown]
# A constant trend in a time series simply becomes the mean of the differenced time series.
#
# Many time series modeling techniques assume that there is no trend, so detrending by differencing can be a useful preprocessing step.
