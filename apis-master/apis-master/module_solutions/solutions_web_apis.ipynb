# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px" />
#
# # Introduction to Web Services and APIs
#
# _Author: Dave Yerrington (SF)_

# %% [markdown]
# One of my first projects as a data scientist was to write a program to download images based on information obtained from an API. My boss told me "you should just have to make requests to a simple REST API endpoint." I nodded along, but I had no idea what half of those words meant.
#
# After this lesson, you will have some idea what those words mean and will know enough to get started interacting with APIs in a secure way.

# %%
import os

import pandas as pd
import requests

# %% [markdown]
# # Introduction to APIs

# %% [markdown]
# ## Data API Example

# %% [markdown]
# An API allows you to use code to interact with a service.

# %% [markdown]
# For instance, Apple offers a freely accessible iTunes Search API.
#
# You can access a resource through this API by pasting this URL into your browser:
#
#     https://itunes.apple.com/search?term=beyonce&entity=musicVideo

# %% [markdown]
# You can also use the Python library `requests` to retrieve this resource.

# %%
# Write code to retrieve the resource
# /scrub/
response = requests.get("https://itunes.apple.com/search?term=beyonce&entity=musicVideo")
search_response = response.json()
search_response
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779783,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939779783?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939779783?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/b1/77/09/b177099e-8896-f8e8-fbd0-32a07043a198/mzvf_4178862957106535709.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2011-05-25T07:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332981,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Partition',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Partition',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/partition/780332981?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/partition/780332981?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/8a/f2/63/8af26302-6331-5bdd-9571-5454c180cc03/mzvf_4516420759660203586.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 22,
#    'trackTimeMillis': 229417,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330565,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Ghost (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Ghost (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/ghost-video/780330565?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/ghost-video/780330565?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/58/d2/27/58d227d6-a63c-9fa0-f2ba-6a7e65cc6b4f/mzvf_7653561767266224652.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 16,
#    'trackTimeMillis': 151827,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330736,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Drunk in Love (feat. Jay Z)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Drunk in Love (feat. Jay Z)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-feat-jay-z/780330736?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-feat-jay-z/780330736?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/f0/e2/25/f0e225c8-1676-dd2c-5980-b9cee6843d78/mzvf_2456950213077026069.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 18,
#    'trackTimeMillis': 381480,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334329,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Credits (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Credits (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/credits-video/780334329?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/credits-video/780334329?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/22/8b/8f/228b8f8d-2c8b-2f16-b942-23943be5e17b/mzvf_6756932481568810544.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': -1.0,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 32,
#    'trackTimeMillis': 154920,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332973,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Yoncé',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Yoncé',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/yonc%C3%A9/780332973?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/yonc%C3%A9/780332973?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/79/4f/23/794f23f8-1878-917e-6b8b-0a3cb163a3a1/mzvf_4781644640929163406.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 21,
#    'trackTimeMillis': 122793,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 1107429221,
#    'trackId': 1107429383,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Lemonade',
#    'trackName': 'Lemonade Film',
#    'collectionCensoredName': 'Lemonade',
#    'trackCensoredName': 'Lemonade Film',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/lemonade-film/1107429383?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/lemonade-film/1107429383?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/c6/a6/70/c6a670d4-2034-894f-e592-178cc0b02be3/mzvf_5879280307237101965.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/100x100bb.jpg',
#    'collectionPrice': 17.99,
#    'trackPrice': -1.0,
#    'releaseDate': '2016-04-25T07:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 13,
#    'trackTimeMillis': 3955327,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332958,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'No Angel (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'No Angel (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/no-angel-video/780332958?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/no-angel-video/780332958?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/48/f8/75/48f8750d-ff9e-a63c-5386-787cba914866/mzvf_6092209891204166583.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 20,
#    'trackTimeMillis': 233320,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334212,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Grown Woman (Bonus Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Grown Woman (Bonus Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780334212?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780334212?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/37/06/b0/3706b09f-21d6-38b5-3be8-a918c4e557c7/mzvf_5612497697990929684.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 31,
#    'trackTimeMillis': 264105,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330422,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Pretty Hurts (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Pretty Hurts (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780330422?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780330422?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/6a/10/45/6a1045d5-3dad-9982-9449-e69a596b4414/mzvf_7222015769450558970.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 15,
#    'trackTimeMillis': 424808,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334051,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': '***Flawless\xa0(feat. Chimamanda Ngozi Adichie) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': '***Flawless\xa0(feat. Chimamanda Ngozi Adichie) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/flawless-feat-chimamanda-ngozi-adichie-video/780334051?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/flawless-feat-chimamanda-ngozi-adichie-video/780334051?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/e0/5a/16/e05a16c5-4aca-023c-654c-18b451538ef5/mzvf_4792366321984468435.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 27,
#    'trackTimeMillis': 252052,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333923,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'XO\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'XO\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780333923?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780333923?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/ff/f2/85/fff28511-9f7e-5ee3-02ad-bb23a219611b/mzvf_5604407000218676243.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 26,
#    'trackTimeMillis': 215977,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330707,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Haunted',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Haunted',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted/780330707?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted/780330707?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/77/07/8f/77078faa-0976-e08e-2eed-b6f3e2d6a2ec/mzvf_7211602600168493298.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 17,
#    'trackTimeMillis': 321087,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334086,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Superpower (feat. Frank Ocean)\xa0[Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Superpower (feat. Frank Ocean)\xa0[Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/superpower-feat-frank-ocean-video/780334086?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/superpower-feat-frank-ocean-video/780334086?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/9e/dc/82/9edc82de-2746-6b66-934d-56fdbb86f489/mzvf_7652955100509840754.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 28,
#    'trackTimeMillis': 324457,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334102,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Heaven\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Heaven\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780334102?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780334102?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/eb/f0/11/ebf011de-c566-fa34-4cec-2558a114686b/mzvf_101281223654512957.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 29,
#    'trackTimeMillis': 235283,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333896,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Rocket\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Rocket\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/rocket-video/780333896?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/rocket-video/780333896?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/e6/ba/a1/e6baa197-689c-62e2-5912-3906b3374c6a/mzvf_1558661197110837054.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 24,
#    'trackTimeMillis': 269608,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333903,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Mine\xa0(feat. Drake) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Mine\xa0(feat. Drake) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780333903?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780333903?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/41/a7/b5/41a7b5b4-5b67-db07-59b8-ed47e8a19faf/mzvf_2290512269237528219.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 25,
#    'trackTimeMillis': 299027,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333890,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Jealous\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Jealous\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780333890?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780333890?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/a8/f3/37/a8f3376e-03c2-c255-6dba-ee9e222638a0/mzvf_6964496073208107037.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 23,
#    'trackTimeMillis': 206505,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334188,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Blue\xa0(feat. Blue Ivy) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Blue\xa0(feat. Blue Ivy) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780334188?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780334188?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/e9/ae/78/e9ae7815-fd5c-34c2-5e10-95a23f8bfa0a/mzvf_8666799494331641553.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 30,
#    'trackTimeMillis': 275240,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330820,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Blow (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Blow (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blow-video/780330820?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blow-video/780330820?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/30/4c/a3/304ca360-efed-382f-4480-03883d1a3450/mzvf_5551005045244709275.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 19,
#    'trackTimeMillis': 325715,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939775882,
#    'trackId': 939778321,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (Platinum Edition)',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (Platinum Edition)',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939778321?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939778321?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/28/40/3a/28403aa0-26c8-4e86-9ff8-1cb1ed66b74d/mzvf_3940585470091964597.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/100x100bb.jpg',
#    'collectionPrice': 24.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 4,
#    'discNumber': 4,
#    'trackCount': 49,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'trackId': 460944314,
#    'artistName': 'Beyoncé',
#    'trackName': '1+1',
#    'trackCensoredName': '1+1',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1/460944314?uo=4',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/100x100bb.jpg',
#    'releaseDate': '2011-08-26T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939777559,
#    'trackId': 939777651,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (Platinum Edition) - EP',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (Platinum Edition) - EP',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939777651?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939777651?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/40/87/23/408723a0-d3d1-07d6-19a9-962abe3fb308/mzvf_2180521475417233646.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779774,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Get Me Bodied',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Get Me Bodied (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/get-me-bodied-live-from-mrs-carter-show-world-tour/939779774?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/get-me-bodied-live-from-mrs-carter-show-world-tour/939779774?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/8f/1b/52/8f1b5284-4c70-7cc0-9b4d-f4e2831f54b3/mzvf_4884655097527391083.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 3,
#    'trackTimeMillis': 291048,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779787,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Heaven',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Heaven (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-live-from-mrs-carter-show-world-tour/939779787?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-live-from-mrs-carter-show-world-tour/939779787?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/46/7c/91/467c9156-4462-5066-1429-ac0388bb7f0b/mzvf_1055942717367203611.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 9,
#    'trackTimeMillis': 279080,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779786,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Partition',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Partition (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/partition-live-from-mrs-carter-show-world-tour/939779786?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/partition-live-from-mrs-carter-show-world-tour/939779786?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/57/e5/e8/57e5e873-41b5-71df-8fb3-ca6ad86895fb/mzvf_7551300350184121925.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 8,
#    'trackTimeMillis': 263657,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779782,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Drunk in Love',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Drunk in Love (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-live-from-mrs-carter-show-world-tour/939779782?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-live-from-mrs-carter-show-world-tour/939779782?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/98/3d/dc/983ddc57-dc93-12e3-ecfd-a8fbc449cd27/mzvf_5029186287690664250.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 6,
#    'trackTimeMillis': 247507,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779768,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Run the World (Girls)',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Run the World (Girls) [Live from Mrs. Carter Show World Tour]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/run-the-world-girls-live-from-mrs-carter-show-world-tour/939779768?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/run-the-world-girls-live-from-mrs-carter-show-world-tour/939779768?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/6f/64/7f/6f647f13-6143-c709-ab16-6696a2c445d1/mzvf_2836103022648365174.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 1,
#    'trackTimeMillis': 241342,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779781,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Haunted',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Haunted (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted-live-from-mrs-carter-show-world-tour/939779781?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted-live-from-mrs-carter-show-world-tour/939779781?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/fb/ec/de/fbecde80-6ecd-ae7b-3d77-b8a93eba693b/mzvf_3941459533292323981.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 5,
#    'trackTimeMillis': 287550,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 91853,
#    'trackId': 291179892,
#    'artistName': 'Mariah Carey, Beyoncé, Mary J. Blige, Rihanna, Fergie, Natasha Bedingfield, Miley Cyrus, Leona Lewis, Carrie Underwood, Keyshia Cole, Ashanti, Ciara & Nicole Scherzinger',
#    'trackName': 'Just Stand Up! (Just Stand Up Live: A Benefit for Stand Up to Cancer)',
#    'trackCensoredName': 'Just Stand Up! (Just Stand Up Live: A Benefit for Stand Up to Cancer)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/mariah-carey/91853?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/just-stand-up-just-stand-up-live-benefit-for-stand/291179892?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video/e5/07/2b/mzm.kewmjxhp..640x352.h264lc.u.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/100x100bb.jpg',
#    'collectionPrice': 1.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-09-11T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 278430,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520037,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Drunk in Love (feat. Jay Z) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
# ...
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'cleaned',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 22,
#    'trackTimeMillis': 229417,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Clean'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520119,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Jealous (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Jealous (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780520119?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780520119?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/61/54/12/61541297-14de-e3ee-2dfa-9e358b77c140/mzvf_4381152036711315105.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 23,
#    'trackTimeMillis': 206505,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 159761791,
#    'trackId': 121692767,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Check On It (feat. Bun B & Slim Thug) - EP',
#    'trackName': 'Check On It (feat. Bun B & Slim Thug)',
#    'collectionCensoredName': 'Check On It (feat. Bun B & Slim Thug) - EP',
#    'trackCensoredName': 'Check On It (feat. Bun B & Slim Thug)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/check-on-it-feat-bun-b-slim-thug/121692767?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/check-on-it-feat-bun-b-slim-thug/121692767?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/90/01/9d/90019d2d-8864-4b61-8dbf-0ddc5df531cc/mzvf_2345545707312627683.640x464.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2003-04-28T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 6,
#    'trackNumber': 6,
#    'trackTimeMillis': 209877,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520271,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Grown Woman (Bonus Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Grown Woman (Bonus Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780520271?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780520271?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/a1/02/c8/a102c8b7-90e3-878b-9051-b41bd4ba28ff/mzvf_5549189897154442801.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 31,
#    'trackTimeMillis': 264105,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520254,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Blue (feat. Blue Ivy) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Blue (feat. Blue Ivy) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780520254?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780520254?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/af/c3/56/afc35695-9286-013b-f43c-87af03c03284/mzvf_8053415805206147926.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 30,
#    'trackTimeMillis': 275240,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'trackId': 300707141,
#    'artistName': 'Beyoncé',
#    'trackName': 'Halo',
#    'trackCensoredName': 'Halo',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/halo/300707141?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/07/d6/6c/07d66caa-a271-994c-84fc-052ec45dcfdf/mzvf_3671979302943111848.640x272.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/100x100bb.jpg',
#    'collectionPrice': 1.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-12-23T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 224190,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520139,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Mine (feat. Drake) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Mine (feat. Drake) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780520139?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780520139?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/aa/a0/93/aaa0932b-e1f9-c28d-8135-d114bf075aae/mzvf_4387526503706804439.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'cleaned',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 25,
#    'trackTimeMillis': 299133,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Clean'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520161,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'XO (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'XO (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780520161?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780520161?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/3b/f5/2d/3bf52d6c-512f-4db3-083e-ce438714c712/mzvf_1844851806602280404.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 26,
#    'trackTimeMillis': 215977,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780519990,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Pretty Hurts (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Pretty Hurts (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780519990?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780519990?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/7b/62/d2/7b62d2c0-718d-73e1-ac41-c05ee5aafd09/mzvf_8457488219596279231.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 15,
#    'trackTimeMillis': 424808,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520250,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Heaven (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Heaven (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780520250?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780520250?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/12/95/ea/1295ea68-ac77-3913-cdbe-c8d26fb7c16c/mzvf_8799090981637352329.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 29,
#    'trackTimeMillis': 235283,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520015,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Haunted (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Haunted (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted-video/780520015?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted-video/780520015?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/b3/a9/84/b3a9842f-e00a-4c00-481f-60c02105a6cd/mzvf_4233101003833819311.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 17,
#    'trackTimeMillis': 321087,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'}]}

# %% [markdown]
# https://itunes.apple.com/search is an example of a **web API endpoint**. By typing this URL followed by `?` and then a sequence of ampersand-separated query terms, you can retrieve information from an iTunes database that Apple maintains.

# %% [markdown]
# ## API Client Libraries

# %% [markdown]
# The URL "https://itunes.apple.com/search?term=beyonce&entity=musicVideo" isn't much fun to read or write. An **API client library** allows you to interact with the service by writing more expressive code in a language such as Python.

# %% [markdown]
# For instance, an API client library for the iTunes API might provide a function like this.

# %%
BASE_URL = "https://itunes.apple.com/"

def get_music_videos_by_artist(artist):
    endpoint = 'search'
    url = f'{BASE_URL}/{endpoint}?term={artist}&entity=musicVideo'
    response = requests.get(url)
    return response.json()

# %% [markdown]
# Then you could retrieve that resource by writing code like this:

# %%
get_music_videos_by_artist('beyonce')
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779783,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939779783?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939779783?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/b1/77/09/b177099e-8896-f8e8-fbd0-32a07043a198/mzvf_4178862957106535709.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/e5/ab/42/e5ab42d9-ce31-160f-d5c7-668b9a0200a2/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2011-05-25T07:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332981,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Partition',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Partition',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/partition/780332981?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/partition/780332981?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/8a/f2/63/8af26302-6331-5bdd-9571-5454c180cc03/mzvf_4516420759660203586.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/89/e8/10/89e8104b-6292-500c-cbf8-d2d60cfa782f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 22,
#    'trackTimeMillis': 229417,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330565,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Ghost (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Ghost (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/ghost-video/780330565?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/ghost-video/780330565?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/58/d2/27/58d227d6-a63c-9fa0-f2ba-6a7e65cc6b4f/mzvf_7653561767266224652.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/ec/6e/40/ec6e403c-86ce-6111-e524-40bbb6a6deca/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 16,
#    'trackTimeMillis': 151827,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330736,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Drunk in Love (feat. Jay Z)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Drunk in Love (feat. Jay Z)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-feat-jay-z/780330736?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-feat-jay-z/780330736?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/f0/e2/25/f0e225c8-1676-dd2c-5980-b9cee6843d78/mzvf_2456950213077026069.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/50/aa/22/50aa22a9-3f97-eb49-19b9-f6929d00d650/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 18,
#    'trackTimeMillis': 381480,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334329,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Credits (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Credits (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/credits-video/780334329?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/credits-video/780334329?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/22/8b/8f/228b8f8d-2c8b-2f16-b942-23943be5e17b/mzvf_6756932481568810544.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/37/5a/99/375a9984-d548-44d2-9bcc-acdc15e05c7c/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': -1.0,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 32,
#    'trackTimeMillis': 154920,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332973,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Yoncé',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Yoncé',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/yonc%C3%A9/780332973?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/yonc%C3%A9/780332973?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/79/4f/23/794f23f8-1878-917e-6b8b-0a3cb163a3a1/mzvf_4781644640929163406.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/05/66/53/05665394-bd25-7553-8371-6a992d19f39a/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 21,
#    'trackTimeMillis': 122793,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 1107429221,
#    'trackId': 1107429383,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Lemonade',
#    'trackName': 'Lemonade Film',
#    'collectionCensoredName': 'Lemonade',
#    'trackCensoredName': 'Lemonade Film',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/lemonade-film/1107429383?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/lemonade-film/1107429383?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/c6/a6/70/c6a670d4-2034-894f-e592-178cc0b02be3/mzvf_5879280307237101965.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video30/v4/fc/be/4e/fcbe4ec2-8b44-1fd0-f3af-ed4dbe998a9d/source/100x100bb.jpg',
#    'collectionPrice': 17.99,
#    'trackPrice': -1.0,
#    'releaseDate': '2016-04-25T07:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 14,
#    'trackNumber': 13,
#    'trackTimeMillis': 3955327,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780332958,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'No Angel (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'No Angel (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/no-angel-video/780332958?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/no-angel-video/780332958?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/48/f8/75/48f8750d-ff9e-a63c-5386-787cba914866/mzvf_6092209891204166583.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/25/e2/4b/25e24b99-44dc-9942-abd4-fa491f123c5f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 20,
#    'trackTimeMillis': 233320,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334212,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Grown Woman (Bonus Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Grown Woman (Bonus Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780334212?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780334212?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/37/06/b0/3706b09f-21d6-38b5-3be8-a918c4e557c7/mzvf_5612497697990929684.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/1d/11/7c/1d117c96-46c0-76d8-71b9-2ae8f6c47596/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 31,
#    'trackTimeMillis': 264105,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330422,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Pretty Hurts (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Pretty Hurts (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780330422?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780330422?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/6a/10/45/6a1045d5-3dad-9982-9449-e69a596b4414/mzvf_7222015769450558970.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/42/9c/06/429c0633-32fb-917b-02a4-066a27601aec/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 15,
#    'trackTimeMillis': 424808,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334051,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': '***Flawless\xa0(feat. Chimamanda Ngozi Adichie) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': '***Flawless\xa0(feat. Chimamanda Ngozi Adichie) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/flawless-feat-chimamanda-ngozi-adichie-video/780334051?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/flawless-feat-chimamanda-ngozi-adichie-video/780334051?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/e0/5a/16/e05a16c5-4aca-023c-654c-18b451538ef5/mzvf_4792366321984468435.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/95/8c/60/958c60c9-2c77-92d6-72d3-c55db04eee12/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 27,
#    'trackTimeMillis': 252052,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333923,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'XO\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'XO\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780333923?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780333923?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/ff/f2/85/fff28511-9f7e-5ee3-02ad-bb23a219611b/mzvf_5604407000218676243.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video6/v4/18/e0/5e/18e05ebf-6a5c-00dc-97be-1c73a4b24ca3/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 26,
#    'trackTimeMillis': 215977,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330707,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Haunted',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Haunted',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted/780330707?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted/780330707?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/77/07/8f/77078faa-0976-e08e-2eed-b6f3e2d6a2ec/mzvf_7211602600168493298.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/bb/1c/9b/bb1c9b47-2148-a540-d9f6-286c12f7e511/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 17,
#    'trackTimeMillis': 321087,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334086,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Superpower (feat. Frank Ocean)\xa0[Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Superpower (feat. Frank Ocean)\xa0[Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/superpower-feat-frank-ocean-video/780334086?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/superpower-feat-frank-ocean-video/780334086?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/9e/dc/82/9edc82de-2746-6b66-934d-56fdbb86f489/mzvf_7652955100509840754.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video/v4/d4/4c/52/d44c5224-3a33-115a-912a-7a0a3134cf0b/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 28,
#    'trackTimeMillis': 324457,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334102,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Heaven\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Heaven\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780334102?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780334102?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/eb/f0/11/ebf011de-c566-fa34-4cec-2558a114686b/mzvf_101281223654512957.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/2a/b9/78/2ab9789c-a4ef-ffca-e1e7-182a5531bd7d/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 29,
#    'trackTimeMillis': 235283,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333896,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Rocket\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Rocket\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/rocket-video/780333896?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/rocket-video/780333896?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/e6/ba/a1/e6baa197-689c-62e2-5912-3906b3374c6a/mzvf_1558661197110837054.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/0e/1b/4c/0e1b4cdd-75eb-6f07-cfb9-930f229f0c8f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 24,
#    'trackTimeMillis': 269608,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333903,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Mine\xa0(feat. Drake) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Mine\xa0(feat. Drake) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780333903?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780333903?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/41/a7/b5/41a7b5b4-5b67-db07-59b8-ed47e8a19faf/mzvf_2290512269237528219.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/64/0b/91/640b916b-fe62-d2f6-416a-97874681f723/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 25,
#    'trackTimeMillis': 299027,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780333890,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Jealous\xa0(Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Jealous\xa0(Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780333890?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780333890?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/a8/f3/37/a8f3376e-03c2-c255-6dba-ee9e222638a0/mzvf_6964496073208107037.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video6/v4/90/ef/a3/90efa3a9-fe3d-ad64-5be4-8a53ab8fa0b9/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 23,
#    'trackTimeMillis': 206505,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780334188,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Blue\xa0(feat. Blue Ivy) [Video]',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Blue\xa0(feat. Blue Ivy) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780334188?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780334188?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/e9/ae/78/e9ae7815-fd5c-34c2-5e10-95a23f8bfa0a/mzvf_8666799494331641553.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/44/52/4e/44524e83-3e40-32cf-dd13-04e12c4683d2/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 30,
#    'trackTimeMillis': 275240,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780330041,
#    'trackId': 780330820,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ',
#    'trackName': 'Blow (Video)',
#    'collectionCensoredName': 'BEYONCÉ',
#    'trackCensoredName': 'Blow (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blow-video/780330820?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blow-video/780330820?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/30/4c/a3/304ca360-efed-382f-4480-03883d1a3450/mzvf_5551005045244709275.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video4/v4/24/84/f9/2484f97c-c3ce-5c31-e2ca-4f78243972f7/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 19,
#    'trackTimeMillis': 325715,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939775882,
#    'trackId': 939778321,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (Platinum Edition)',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (Platinum Edition)',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939778321?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939778321?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/28/40/3a/28403aa0-26c8-4e86-9ff8-1cb1ed66b74d/mzvf_3940585470091964597.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video2/v4/43/9f/4e/439f4ecb-0fc2-4a6d-06cd-4a0961b785aa/source/100x100bb.jpg',
#    'collectionPrice': 24.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 4,
#    'discNumber': 4,
#    'trackCount': 49,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'trackId': 460944314,
#    'artistName': 'Beyoncé',
#    'trackName': '1+1',
#    'trackCensoredName': '1+1',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1/460944314?uo=4',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video128/v4/ef/86/89/ef868956-118d-80d2-7579-9f8adee70d02/source/100x100bb.jpg',
#    'releaseDate': '2011-08-26T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939777559,
#    'trackId': 939777651,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (Platinum Edition) - EP',
#    'trackName': '1+1',
#    'collectionCensoredName': 'BEYONCÉ (Platinum Edition) - EP',
#    'trackCensoredName': '1+1 (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939777651?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/1-1-live-from-mrs-carter-show-world-tour/939777651?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/40/87/23/408723a0-d3d1-07d6-19a9-962abe3fb308/mzvf_2180521475417233646.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video1/v4/9a/00/3f/9a003fac-3845-aca1-7468-3c3b185f9c41/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 7,
#    'trackTimeMillis': 287635,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779774,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Get Me Bodied',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Get Me Bodied (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/get-me-bodied-live-from-mrs-carter-show-world-tour/939779774?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/get-me-bodied-live-from-mrs-carter-show-world-tour/939779774?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/8f/1b/52/8f1b5284-4c70-7cc0-9b4d-f4e2831f54b3/mzvf_4884655097527391083.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video5/v4/c8/1b/bf/c81bbf5e-3df7-fbea-3e4d-1b12223528e8/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 3,
#    'trackTimeMillis': 291048,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779787,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Heaven',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Heaven (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-live-from-mrs-carter-show-world-tour/939779787?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-live-from-mrs-carter-show-world-tour/939779787?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/46/7c/91/467c9156-4462-5066-1429-ac0388bb7f0b/mzvf_1055942717367203611.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video3/v4/94/4a/bc/944abc60-d60d-263e-d7b8-657255add512/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 9,
#    'trackTimeMillis': 279080,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779786,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Partition',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Partition (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/partition-live-from-mrs-carter-show-world-tour/939779786?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/partition-live-from-mrs-carter-show-world-tour/939779786?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/57/e5/e8/57e5e873-41b5-71df-8fb3-ca6ad86895fb/mzvf_7551300350184121925.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video6/v4/29/f3/ed/29f3ed9d-d6ee-7c02-f2e8-f5e32466a595/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 8,
#    'trackTimeMillis': 263657,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779782,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Drunk in Love',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Drunk in Love (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-live-from-mrs-carter-show-world-tour/939779782?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/drunk-in-love-live-from-mrs-carter-show-world-tour/939779782?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/98/3d/dc/983ddc57-dc93-12e3-ecfd-a8fbc449cd27/mzvf_5029186287690664250.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video3/v4/d4/0f/c8/d40fc8ea-3049-fbb0-516e-263e78dadab1/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 6,
#    'trackTimeMillis': 247507,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779768,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Run the World (Girls)',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Run the World (Girls) [Live from Mrs. Carter Show World Tour]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/run-the-world-girls-live-from-mrs-carter-show-world-tour/939779768?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/run-the-world-girls-live-from-mrs-carter-show-world-tour/939779768?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/6f/64/7f/6f647f13-6143-c709-ab16-6696a2c445d1/mzvf_2836103022648365174.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video5/v4/f1/3f/52/f13f523b-faaa-7dae-bcd3-1399c33ee248/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 1,
#    'trackTimeMillis': 241342,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 939779719,
#    'trackId': 939779781,
#    'artistName': 'Beyoncé',
#    'collectionName': 'BEYONCÉ (More Only) - EP',
#    'trackName': 'Haunted',
#    'collectionCensoredName': 'BEYONCÉ (More Only) - EP',
#    'trackCensoredName': 'Haunted (Live from Mrs. Carter Show World Tour)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted-live-from-mrs-carter-show-world-tour/939779781?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted-live-from-mrs-carter-show-world-tour/939779781?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/fb/ec/de/fbecde80-6ecd-ae7b-3d77-b8a93eba693b/mzvf_3941459533292323981.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video3/v4/de/b0/ae/deb0aea6-80de-c91e-e8b5-a408b9bbef64/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2014-11-24T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 2,
#    'discNumber': 2,
#    'trackCount': 16,
#    'trackNumber': 5,
#    'trackTimeMillis': 287550,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Explicit'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 91853,
#    'trackId': 291179892,
#    'artistName': 'Mariah Carey, Beyoncé, Mary J. Blige, Rihanna, Fergie, Natasha Bedingfield, Miley Cyrus, Leona Lewis, Carrie Underwood, Keyshia Cole, Ashanti, Ciara & Nicole Scherzinger',
#    'trackName': 'Just Stand Up! (Just Stand Up Live: A Benefit for Stand Up to Cancer)',
#    'trackCensoredName': 'Just Stand Up! (Just Stand Up Live: A Benefit for Stand Up to Cancer)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/mariah-carey/91853?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/just-stand-up-just-stand-up-live-benefit-for-stand/291179892?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video/e5/07/2b/mzm.kewmjxhp..640x352.h264lc.u.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/f3/23/95/f32395cb-9c3d-3c9f-76a1-0e25767aa9ca/source/100x100bb.jpg',
#    'collectionPrice': 1.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-09-11T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 278430,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520037,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Drunk in Love (feat. Jay Z) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
# ...
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'cleaned',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 22,
#    'trackTimeMillis': 229417,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Clean'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520119,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Jealous (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Jealous (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780520119?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/jealous-video/780520119?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/61/54/12/61541297-14de-e3ee-2dfa-9e358b77c140/mzvf_4381152036711315105.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video6/v4/e3/9d/04/e39d049d-98c7-6540-a4b6-69e80bb0b87f/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 23,
#    'trackTimeMillis': 206505,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 159761791,
#    'trackId': 121692767,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Check On It (feat. Bun B & Slim Thug) - EP',
#    'trackName': 'Check On It (feat. Bun B & Slim Thug)',
#    'collectionCensoredName': 'Check On It (feat. Bun B & Slim Thug) - EP',
#    'trackCensoredName': 'Check On It (feat. Bun B & Slim Thug)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/check-on-it-feat-bun-b-slim-thug/121692767?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/check-on-it-feat-bun-b-slim-thug/121692767?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/90/01/9d/90019d2d-8864-4b61-8dbf-0ddc5df531cc/mzvf_2345545707312627683.640x464.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Video/v4/02/69/83/026983c6-54cb-b071-a801-dd559de90c71/source/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2003-04-28T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 6,
#    'trackNumber': 6,
#    'trackTimeMillis': 209877,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520271,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Grown Woman (Bonus Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Grown Woman (Bonus Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780520271?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/grown-woman-bonus-video/780520271?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/a1/02/c8/a102c8b7-90e3-878b-9051-b41bd4ba28ff/mzvf_5549189897154442801.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video/v4/0a/26/75/0a2675e7-db32-fbcd-df4e-bd53b4cec3e9/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 31,
#    'trackTimeMillis': 264105,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520254,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Blue (feat. Blue Ivy) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Blue (feat. Blue Ivy) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780520254?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/blue-feat-blue-ivy-video/780520254?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/af/c3/56/afc35695-9286-013b-f43c-87af03c03284/mzvf_8053415805206147926.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video118/v4/4b/e7/c2/4be7c284-00d4-a148-c00c-cc50652d038e/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 30,
#    'trackTimeMillis': 275240,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'trackId': 300707141,
#    'artistName': 'Beyoncé',
#    'trackName': 'Halo',
#    'trackCensoredName': 'Halo',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/halo/300707141?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/07/d6/6c/07d66caa-a271-994c-84fc-052ec45dcfdf/mzvf_3671979302943111848.640x272.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Video/v4/e1/6c/3d/e16c3d88-c361-4804-c063-02ff96259e79/source/100x100bb.jpg',
#    'collectionPrice': 1.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2008-12-23T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'trackTimeMillis': 224190,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520139,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Mine (feat. Drake) [Video]',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Mine (feat. Drake) [Video]',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780520139?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/mine-feat-drake-video/780520139?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video118/v4/aa/a0/93/aaa0932b-e1f9-c28d-8135-d114bf075aae/mzvf_4387526503706804439.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video4/v4/9c/12/45/9c1245d5-f0db-2349-7d15-03c52a7f7fb5/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'cleaned',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 25,
#    'trackTimeMillis': 299133,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop',
#    'contentAdvisoryRating': 'Clean'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520161,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'XO (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'XO (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780520161?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/xo-video/780520161?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video128/v4/3b/f5/2d/3bf52d6c-512f-4db3-083e-ce438714c712/mzvf_1844851806602280404.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Video4/v4/c6/86/7f/c6867fc0-8a79-dc7e-7b2d-eb84f574625e/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 26,
#    'trackTimeMillis': 215977,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780519990,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Pretty Hurts (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Pretty Hurts (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780519990?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/pretty-hurts-video/780519990?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video125/v4/7b/62/d2/7b62d2c0-718d-73e1-ac41-c05ee5aafd09/mzvf_8457488219596279231.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video6/v4/3e/c5/77/3ec57734-9a81-9fa6-9d87-4e85f7addf57/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 15,
#    'trackTimeMillis': 424808,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520250,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Heaven (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Heaven (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780520250?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/heaven-video/780520250?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/12/95/ea/1295ea68-ac77-3913-cdbe-c8d26fb7c16c/mzvf_8799090981637352329.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video4/v4/e9/e1/5e/e9e15ed7-93aa-a85f-0989-030d117f9b57/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 29,
#    'trackTimeMillis': 235283,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'},
#   {'wrapperType': 'track',
#    'kind': 'music-video',
#    'artistId': 1419227,
#    'collectionId': 780519939,
#    'trackId': 780520015,
#    'artistName': 'Beyoncé',
#    'collectionName': 'Beyoncé (Deluxe)',
#    'trackName': 'Haunted (Video)',
#    'collectionCensoredName': 'Beyoncé (Deluxe)',
#    'trackCensoredName': 'Haunted (Video)',
#    'artistViewUrl': 'https://itunes.apple.com/us/artist/beyonc%C3%A9/1419227?uo=4',
#    'collectionViewUrl': 'https://itunes.apple.com/us/music-video/haunted-video/780520015?uo=4',
#    'trackViewUrl': 'https://itunes.apple.com/us/music-video/haunted-video/780520015?uo=4',
#    'previewUrl': 'https://video-ssl.itunes.apple.com/apple-assets-us-std-000001/Video115/v4/b3/a9/84/b3a9842f-e00a-4c00-481f-60c02105a6cd/mzvf_4233101003833819311.640x480.h264lc.U.p.m4v',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Video/v4/ed/4b/82/ed4b821d-2eb7-a56d-df0c-a609db016bfc/source/100x100bb.jpg',
#    'collectionPrice': 15.99,
#    'trackPrice': 1.99,
#    'releaseDate': '2013-12-13T08:00:00Z',
#    'collectionExplicitness': 'cleaned',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 33,
#    'trackNumber': 17,
#    'trackTimeMillis': 321087,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Pop'}]}

# %% [markdown]
# ## Model API Example

# %% [markdown]
# We just saw an example of an API that gives you access to data. There are also APIs that give you access to predictions from trained machine learning models.

# %% [markdown]
# For instance, Google has a "Cloud Vision API" that allows you to post an image and get back a list of labels that apply to that image, as predicted by a trained machine learning model. [Try it here](https://cloud.google.com/vision/docs/drag-and-drop).

# %% [markdown]
# Developers who need this kind of image recognition capability can pay to send images to the underlying API and retrieve responses through their application code.

# %% [markdown]
# ## How APIs Help

# %% [markdown]
# **Data APIs:**
# - *As a consumer:* You need data to do data science. Many organizations provide access to their data through an API, so knowing how to interact with APIs increases the range of data science projects that you can tackle. In addition, it allows you to get just the data you need rather than an entire set of files or database.
# - *As a producer:* Exposing a valuable data set through an API allows you to provide access to that data set in a controlled way; for instance, it allows you to charge for each query above a certain limit.
#
# **Model APIs:**
# - *As a consumer:* Accessing a model API allows you to use a model someone else has already trained rather than building it yourself.
# - *As a producer:* Building a model API allows you to sell access to a model or make it available to your organization's applications without having to write application code yourself.

# %% [markdown]
# Each API has its own structure, authentication methods, and client libraries. As a result, no single lesson can teach you everything you need to know to use any arbitrary API effectively. What we will aim to do is to teach you enough to get you started with data APIs. A well-maintained data API will have documentation that will get you the rest of the way with that specific service.

# %% [markdown]
# # Notes on Web Scraping
#
# - Using code to obtain data from a website without going through an external API is called **web scraping**.
# - Many websites provide rules for web scraping in a `robots.txt` file. ([Example](http://www.espn.com/robots.txt))
# - Scraping a website is fine if no API is available, you follow any rules in a `robots.txt` file, and the amount of traffic you generate is not too large.
# - A website may block you IP address if you violate these principles.
# - This lesson's README provides links to webs scraping resources.

# %% [markdown]
# # Famous APIs
#
# ## Facebook Graph API
#
# Facebook provides an API for interacting with their service in the following ways:
#
# - View your posts
# - View websites, people, posts, pages that you've liked
# - View activity on apps from you and your friends
#   - Movies watched
#   - Music listened
#   - Games played
# - View places traveled / check-ins
#
# **Potential Project Ideas**
#
# - Determining Latent Characteristics
# - Friends Activity
# - Political Classification
# - Text Mining
# - Friend Classifier
# - Trending Topics
# - Recommenders
# - Feature Importances
# - Taste Profiling
# - Hipster Detector
# - Sub-group Identification
# - Checkin-Prediction
# - Relationship Forcasting
# - Relationship Classification
# - Sentiment Analysis
# - Popularity Projection
# - Personal Analytics
# - Friend Similarity Prediction
# - N-Gram Analysis
# - Topic Modeling

# %% [markdown]
# <a id='yelp'></a>
# ##  Yelp API
#
# Yelp provides a way for developers to access:
#
# - Reviews
#  - Services
#  - Restaraunts / Bars / Cafes
#  - Businesses
# - Business meta-data
#
# **Potential Project Ideas**
#
# - Topic Modeling
# - Text Mining
# - Sentiment Analysis
# - Funny / Cool / Interesting Classification
# - Music Genre Classification
# - Parking Index Classification
# - Characteristics Profiling
# - Hipster Index
# - Ideal Activities
# - Friend Recommender
# - Venue Recommender
# - Sports Bar Classifcation
# - Where is the best [whatever] in [neighborhood]

# %% [markdown]
# <a id='echonest'></a>
# ## Echonest
#
# Echonest consolidates access to many entertainment service APIs in one place.  It has a huge list of features and connected services including:
#
# - Spotify
# - Pandora
# - Rdio
# - Gracenote
# - SoundHound
# - Shazam
#
# **Some Echonest features:**
#
# - Music waveform identification (like Shazam, Soundhound music ID)
# - Playlist recommendations
# - Detailed artist, album, and track lookup
#  - Bio / Origins / Contemporaries / Noteworthy Accomplishments
#  - Official twitter / website / social media links
#  - BPM / Mood / Popularity / Genre(s)
#  - Images / Videos / Media
# - Detailed movie, actor, product lookup
# - Concert Schedules and ticket metadata

# %% [markdown]
# # API Structure

# %% [markdown]
# ## REST Architecture

# %% [markdown]
# Many APIs follow a set of design principles called REST. Here are the most important of those principles for our purposes:
#
# - Each resource consists of text in XML or (more often) JSON format.
# - Each resource has exactly one "address" (URL).
# - Each resource contains links to related resources.
# - Requests use a standard set of verbs:
#     - POST -- create a resource
#     - GET -- retrieve a resource
#     - PATCH -- update a resource
#     - DELETE -- delete a resource

# %% [markdown]
# ## URLs

# %% [markdown]
# A URL specifies where a resource can be found on the web.
#
# ![URL](../assets/images/http1-url-structure.png)

# %% [markdown]
# ## Response Structure

# %% [markdown]
# A response to an API request contains a status code as well as the requested resource (as well as some additional metadata).

# %% [markdown]
# ### Status Codes
#
# Status codes provide information about the status of a request, such as whether it succeeded or failed:
#
# - 100-199: Informational
# - 200-299: Success
# - 300-399: Redirect
# - 400-499: Client error
#     - 400: Bad request
#     - 403: Forbidden
#     - 404: Not Found
# - 500-599: Server error

# %% [markdown]
# ### JSON
#
# The most common format for the body of an HTTP request is JSON.
#
# "JSON" is short for _JavaScript Object Notation_. JSON is called "JSON" because a JSON string is valid code in a programming language called Javascript that is used for web programming. It looks very similar to Python code. It is just a nested collection of objects similar to Python dictionaries ("objects" in Javascript) and lists ("arrays" in Javascript).
#
# **JSON Components:**
#
# |Description | Javascript name | Python counterpart |
# |----|-----|----|
# |Collection of key/value pairs | object | dict |
# |Ordered collection of values | array | list |

# %% [markdown]
# **JSON Example** The JSON data below comes from Google's Geocode API, which allows you to get geographical information for an address.

# %%
google_response = {
  "results": [
    {
      "address_components": [
        {
          "long_name": "225",
          "short_name": "225",
          "types": [
            "street_number"
          ]
        },
        {
          "long_name": "Bush Street",
          "short_name": "Bush St",
          "types": [
            "route"
          ]
        },
        {
          "long_name": "Financial District",
          "short_name": "Financial District",
          "types": [
            "neighborhood",
            "political"
          ]
        },
        {
          "long_name": "San Francisco",
          "short_name": "SF",
          "types": [
            "locality",
            "political"
          ]
        },
        {
          "long_name": "San Francisco County",
          "short_name": "San Francisco County",
          "types": [
            "administrative_area_level_2",
            "political"
          ]
        },
        {
          "long_name": "California",
          "short_name": "CA",
          "types": [
            "administrative_area_level_1",
            "political"
          ]
        },
        {
          "long_name": "United States",
          "short_name": "US",
          "types": [
            "country",
            "political"
          ]
        },
        {
          "long_name": "94104",
          "short_name": "94104",
          "types": [
            "postal_code"
          ]
        }
      ],
      "formatted_address": "225 Bush St, San Francisco, CA 94104, USA",
      "geometry": {
        "location": {
          "lat": 37.7908343,
          "lng": -122.4015725
        },
        "location_type": "ROOFTOP",
        "viewport": {
          "northeast": {
            "lat": 37.7921832802915,
            "lng": -122.4002235197085
          },
          "southwest": {
            "lat": 37.7894853197085,
            "lng": -122.4029214802915
          }
        }
      },
      "place_id": "ChIJZXDI4YmAhYAReSK9_qXi2Oo",
      "types": [
        "street_address"
      ]
    }
  ],
  "status": "OK"
}

# %% [markdown]
# **Exercise (8 mins., pair programming)**

# %% [markdown]
# For these exercises, go to https://codebeautify.org/jsonviewer, Paste the JSON provided below into the JSON Input box, and click "Beautify."

# %% [markdown]
# ```javascript
# [{"source":"Twitter for iPhone","text":"If the E.U. wants to further increase their already massive tariffs and barriers on U.S. companies doing business there, we will simply apply a Tax on their Cars which freely pour into the U.S. They make it impossible for our cars (and more) to sell there. Big trade imbalance!","created_at":"Sat Mar 03 17:53:50 +0000 2018","retweet_count":22641,"favorite_count":87398,"is_retweet":false,"id_str":"969994273121820672"},{"source":"Twitter for iPhone","text":"The United States has an $800 Billion Dollar Yearly Trade Deficit because of our “very stupid” trade deals and policies. Our jobs and wealth are being given to other countries that have taken advantage of us for years. They laugh at what fools our leaders have been. No more!","created_at":"Sat Mar 03 17:43:26 +0000 2018","retweet_count":22563,"favorite_count":90540,"is_retweet":false,"id_str":"969991653393039361"}]
# ```

# %% [markdown]
# Identify the structure of the JSON:

# %% [markdown]
# - What type of structure is it at the top level?

# %% [markdown]
# /scrub/
#
# array

# %% [markdown]
# - How many items does that structure contain?

# %% [markdown]
# /scrub/
#
# 2

# %% [markdown]
# - What type of structure is each of those items?

# %% [markdown]
# /scrub/
#
# object

# %% [markdown]
# - What are the keys in each of those structures?

# %% [markdown]
# /scrub/
#
# source, text, created_at, retweet_count, favorite_count, is_retweet, id_str

# %% [markdown]
# - **BONUS:** Write Python code to extract the latitude and longitude from `google_response`.
#
# *Tip:* Work incrementally, digging into the JSON one level at a time.

# %%
# /scrub/
google_response['results'][0]['geometry']['location']
# Out:
# {'lat': 37.7908343, 'lng': -122.4015725}

# %% [markdown]
# $\blacksquare$

# %% [markdown]
# **Note:** Although JSON looks a lot like Python, its syntax differs from that of Python lists and dictionaries in a few ways:
#
# - The JSON counterpart of Python strings must be written with double quotes, whereas Python strings can be written with either double or single quotes.
# - The JSON counterpart of Python's `None` object is `null`.
# - JSON uses "true" and "false" where Python uses "True" and "False".
# - Unlike Python, JSON does not allow trailing commas at the end of an object or array definition.

# %% [markdown]
# <a name="guided-practice"></a>
# # Guided practice: Pulling data from APIs

# %% [markdown]
# Let's use the Star Wars API (SWAPI) to retrieve data about Obi-Wan Kenobi. (This API is perhaps a little frivolous, but it's a good one to practice with because it require registering and setting up authentication.)
#
# Referencing the [SWAPI Documentation](http://swapi.co/documentation), lets create a query to search for characters with "obi" in their name.

# %% [markdown]
# /scrub/
#
# https://swapi.co/api/people/?format=json&search=obi

# %% [markdown]
# ```javascript
# {
#     "count": 1,
#     "next": null,
#     "previous": null,
#     "results": [
#         {
#             "name": "Obi-Wan Kenobi",
#             "height": "182",
#             "mass": "77",
#             "hair_color": "auburn, white",
#             "skin_color": "fair",
#             "eye_color": "blue-gray",
#             "birth_year": "57BBY",
#             "gender": "male",
#             "homeworld": "http://swapi.co/api/planets/20/",
#             "films": [
#                 "http://swapi.co/api/films/2/",
#                 "http://swapi.co/api/films/5/",
#                 "http://swapi.co/api/films/4/",
#                 "http://swapi.co/api/films/6/",
#                 "http://swapi.co/api/films/3/",
#                 "http://swapi.co/api/films/1/"
#             ],
#             "species": ["http://swapi.co/api/species/1/"],
#             "vehicles": ["http://swapi.co/api/vehicles/38/"],
#             "starships": [
#                 "http://swapi.co/api/starships/48/",
#                 "http://swapi.co/api/starships/59/",
#                 "http://swapi.co/api/starships/64/",
#                 "http://swapi.co/api/starships/65/",
#                 "http://swapi.co/api/starships/74/"
#             ],
#             "created": "2014-12-10T16:16:29.192000Z",
#             "edited": "2014-12-20T21:17:50.325000Z",
#             "url": "http://swapi.co/api/people/10/"
#         }
#     ]
# }
# ```

# %% [markdown]
# <a id='submit'></a>
# **Exercise (12 mins., in pairs)**.

# %% [markdown]
# - Use the `requests` library to retrieve a response from SWAPI at the URL above. Then print its JSON contents

# %%
# /scrub/
response = requests.get("http://swapi.co/api/people/10/")
response.json()
# Out:
# {'name': 'Obi-Wan Kenobi',
#  'height': '182',
#  'mass': '77',
#  'hair_color': 'auburn, white',
#  'skin_color': 'fair',
#  'eye_color': 'blue-gray',
#  'birth_year': '57BBY',
#  'gender': 'male',
#  'homeworld': 'https://swapi.co/api/planets/20/',
#  'films': ['https://swapi.co/api/films/2/',
#   'https://swapi.co/api/films/5/',
#   'https://swapi.co/api/films/4/',
#   'https://swapi.co/api/films/6/',
#   'https://swapi.co/api/films/3/',
#   'https://swapi.co/api/films/1/'],
#  'species': ['https://swapi.co/api/species/1/'],
#  'vehicles': ['https://swapi.co/api/vehicles/38/'],
#  'starships': ['https://swapi.co/api/starships/48/',
#   'https://swapi.co/api/starships/59/',
#   'https://swapi.co/api/starships/64/',
#   'https://swapi.co/api/starships/65/',
#   'https://swapi.co/api/starships/74/'],
#  'created': '2014-12-10T16:16:29.192000Z',
#  'edited': '2014-12-20T21:17:50.325000Z',
#  'url': 'https://swapi.co/api/people/10/'}

# %% [markdown]
# Print the response object you got back from `requests.get` above. What information is it giving you in square brackets?

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# /scrub/
#
# It is giving the response code -- in this case, "200" indicating success.

# %% [markdown]
# - Use `requests` to retrieve three additional responses from SWAPI, and print their contents.

# %% [markdown]
# - Run the cell below to install the SWAPI Python client.

# %%
# !conda install -y -c anaconda ujson
# !pip install swapi
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/gGandenberger/anaconda3/envs/py37
#
#   added / updated specs:
#     - ujson
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2018.12.5  |                0         123 KB  anaconda
#     openssl-1.1.1              |       h1de35cc_0         4.6 MB  anaconda
#     ujson-1.35                 |   py37h1de35cc_0          25 KB  anaconda
#     certifi-2018.11.29         |           py37_0         145 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     ujson:           1.35-py37h1de35cc_0 anaconda
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.03.07-0                 --> 2018.12.5-0       anaconda
#     certifi:         2018.11.29-py37_0            --> 2018.11.29-py37_0 anaconda
#     openssl:         1.1.1-h1de35cc_0             --> 1.1.1-h1de35cc_0  anaconda
#
#
# Downloading and Extracting Packages
# ca-certificates-2018 | 123 KB    | ##################################### | 100%
# openssl-1.1.1        | 4.6 MB    | ##################################### | 100%
# ujson-1.35           | 25 KB     | ##################################### | 100%
# certifi-2018.11.29   | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: swapi in /Users/gGandenberger/anaconda3/envs/py37/lib/python3.7/site-packages (0.1.3)
# Collecting six==1.8.0 (from swapi)
#   Downloading https://files.pythonhosted.org/packages/a2/4b/2b4532b4eba116a02fc0b5e0b3540a073a61c003b7b6293b7b884afa8ff1/six-1.8.0-py2.py3-none-any.whl
# Collecting ujson==1.33 (from swapi)
#   Downloading https://files.pythonhosted.org/packages/98/8c/47949a4e454b7ee27cf82a81735414187368fb94bae94de0291903c9881b/ujson-1.33.zip (197kB)
#     100% |████████████████████████████████| 204kB 5.6MB/s
# Requirement already satisfied: requests==2.5.0 in /Users/gGandenberger/anaconda3/envs/py37/lib/python3.7/site-packages (from swapi) (2.5.0)
# Building wheels for collected packages: ujson
#   Running setup.py bdist_wheel for ujson ... done
#   Stored in directory: /Users/gGandenberger/Library/Caches/pip/wheels/9c/43/b5/e372ab2a0387c074de2e1aaff86ea1d331bcb8618071dcf7c0
# Successfully built ujson
# madeye 0.1.0 requires keras, which is not installed.
# madeye 0.1.0 requires mlflow, which is not installed.
# madeye 0.1.0 requires tensorflow, which is not installed.
# thinc 6.12.0 has requirement six<2.0.0,>=1.10.0, but you'll have six 1.8.0 which is incompatible.
# spacy 2.0.16 has requirement requests<3.0.0,>=2.13.0, but you'll have requests 2.5.0 which is incompatible.
# spacy 2.0.16 has requirement ujson>=1.35, but you'll have ujson 1.33 which is incompatible.
# pytest 3.9.3 has requirement six>=1.10.0, but you'll have six 1.8.0 which is incompatible.
# prompt-toolkit 2.0.6 has requirement six>=1.9.0, but you'll have six 1.8.0 which is incompatible.
# html5lib 1.0.1 has requirement six>=1.9, but you'll have six 1.8.0 which is incompatible.
# Installing collected packages: six, ujson
#   Found existing installation: six 1.11.0
#     Uninstalling six-1.11.0:
#       Successfully uninstalled six-1.11.0
#   Found existing installation: ujson 1.35
#     Uninstalling ujson-1.35:
#       Successfully uninstalled ujson-1.35
# Successfully installed six-1.8.0 ujson-1.33
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# - Run the cell below to use the SWAPI Python client to get data on the character Luke and the planet Tatooine.

# %%
import swapi

luke = swapi.get_person(1)
tatooine = swapi.get_planet(1)

# %% [markdown]
# - The `swapi` Python client not only makes it easier to retrieve resources by constructing the relevant URLs for you but also returns structured Python objects instead of JSON blobs. Run the cells below to see what methods and attributes the object `luke` has.

# %%
# See documentation for the `People` class, of which `luke` is an instance
help(luke)
# Out:
# Help on People in module swapi.models object:
#
# class People(BaseModel)
#  |  People(raw_data)
#  |
#  |  Representing a single person
#  |
#  |  Method resolution order:
#  |      People
#  |      BaseModel
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, raw_data)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  get_films(self)
#  |
#  |  get_homeworld(self)
#  |
#  |  get_species(self)
#  |
#  |  get_starships(self)
#  |
#  |  get_vehicles(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseModel:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# See the names of all methods and attributes of `luke`.
# There is no way to tell which are methods and attributes,
# except to the extent that the package authors followed
# the convention of using verb phrases for method names
# and not for attribute names.
# "Dunder" methods (with double underscores at the beginning
# and end of their names) play special roles behind the
# scenes and are not meant to be accessed directly.
dir(luke)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'birth_year',
#  'created',
#  'edited',
#  'eye_color',
#  'films',
#  'gender',
#  'get_films',
#  'get_homeworld',
#  'get_species',
#  'get_starships',
#  'get_vehicles',
#  'hair_color',
#  'height',
#  'homeworld',
#  'mass',
#  'name',
#  'skin_color',
#  'species',
#  'starships',
#  'url',
#  'vehicles']

# %% [markdown]
# - Print at least three attributes of the `luke` object. (If you get something that looks like `<bound method XYZ>`, then you are accessing a method rather than an attribute.)

# %%
# /scrub/

print(luke.starships)
print(luke.get_starships)
print(luke.name)
# Out:
# ['https://swapi.co/api/starships/12/', 'https://swapi.co/api/starships/22/']
# <bound method People.get_starships of <Person - Luke Skywalker>>
# Luke Skywalker

# %% [markdown]
# - Call at least one of `luke`'s methods.

# %%
# /scrub/

luke.get_starships()
# Out:
# <StarshipQuerySet - 2>

# %% [markdown]
# - Use the same approach to find out what attributes and methods the object `tatooine` has. Print at least one of its attributes, and call at least one of its methods.

# %%
#  /scrub/
help(tatooine)
# Out:
# Help on Planet in module swapi.models object:
#
# class Planet(BaseModel)
#  |  Planet(raw_data)
#  |
#  |  Method resolution order:
#  |      Planet
#  |      BaseModel
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, raw_data)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  get_films(self)
#  |
#  |  get_residents(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseModel:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# /scrub/
dir(tatooine)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'climate',
#  'created',
#  'diameter',
#  'edited',
#  'films',
#  'get_films',
#  'get_residents',
#  'gravity',
#  'name',
#  'orbital_period',
#  'population',
#  'residents',
#  'rotation_period',
#  'surface_water',
#  'terrain',
#  'url']

# %%
# /scrub/
tatooine.get_films()
# Out:
# <FilmQuerySet - 5>

# %%
# /scrub/
tatooine.population
# Out:
# '200000'

# %% [markdown]
# - **BONUS:** Query SWAPI from the command line using the tool `curl`. This is a third way to access an API resource, in addition to entering it in your browser's address bar or running Python code. Try running this command in your terminal:
#
#     `curl http https://swapi.co/api/people/1/`

# %% [markdown]
# /scrub/
#
# ```javascript
# {
# 	"name": "Luke Skywalker",
# 	"height": "172",
# 	"mass": "77",
# 	"hair_color": "blond",
# 	"skin_color": "fair",
# 	"eye_color": "blue",
# 	"birth_year": "19BBY",
# 	"gender": "male",
# 	"homeworld": "https://swapi.co/api/planets/1/",
# 	"films": [
# 		"https://swapi.co/api/films/2/",
# 		"https://swapi.co/api/films/6/",
# 		"https://swapi.co/api/films/3/",
# 		"https://swapi.co/api/films/1/",
# 		"https://swapi.co/api/films/7/"
# 	],
# 	"species": [
# 		"https://swapi.co/api/species/1/"
# 	],
# 	"vehicles": [
# 		"https://swapi.co/api/vehicles/14/",
# 		"https://swapi.co/api/vehicles/30/"
# 	],
# 	"starships": [
# 		"https://swapi.co/api/starships/12/",
# 		"https://swapi.co/api/starships/22/"
# 	],
# 	"created": "2014-12-09T13:50:51.644000Z",
# 	"edited": "2014-12-20T21:17:56.891000Z",
# 	"url": "https://swapi.co/api/people/1/"
# }
# ```

# %% [markdown]
# - **BONUS:** Use the SWAPI Python client to get additional data.

# %% [markdown]
# $\blacksquare$

# %% [markdown]
# **IMPORTANT CLEANUP STEP:** Installing the swapi client library might have involved downgrading `matplotlib` in a way that will cause problems later. Run this cell to reinstall the most recent version of `matplotlib`:

# %%
# !pip install --upgrade six
# !conda upgrade -y matplotlib
# Out:
# Collecting six
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# madeye 0.1.0 requires keras, which is not installed.
# madeye 0.1.0 requires mlflow, which is not installed.
# madeye 0.1.0 requires tensorflow, which is not installed.
# swapi 0.1.3 has requirement six==1.8.0, but you'll have six 1.12.0 which is incompatible.
# spacy 2.0.16 has requirement requests<3.0.0,>=2.13.0, but you'll have requests 2.5.0 which is incompatible.
# spacy 2.0.16 has requirement ujson>=1.35, but you'll have ujson 1.33 which is incompatible.
# Installing collected packages: six
#   Found existing installation: six 1.8.0
#     Uninstalling six-1.8.0:
#       Successfully uninstalled six-1.8.0
# Successfully installed six-1.12.0
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/gGandenberger/anaconda3/envs/py37
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.11.29         |           py37_0         145 KB
#     ca-certificates-2018.12.5  |                0         123 KB
#     ------------------------------------------------------------
#                                            Total:         268 KB
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.12.5-0       anaconda --> 2018.12.5-0
#     certifi:         2018.11.29-py37_0 anaconda --> 2018.11.29-py37_0
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1-h1de35cc_0  anaconda --> 1.1.1a-h1de35cc_0
#
#
# Downloading and Extracting Packages
# certifi-2018.11.29   | 145 KB    | ##################################### | 100%
# ca-certificates-2018 | 123 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# # API Authentication
#
# The owners of public APIs typically require users to register and set up API keys or access tokens in order to make more than a few requests. Requiring keys or tokens allows them to track how many requests each user is making. Often the owner of a public API provides a free service tier that allows maybe a few hundred requests per day (e.g. for personal users) and paid service tiers that allow more requests (e.g. for developers of apps that rely on the API).

# %% [markdown]
# ## Example: Using a Bit.ly Access Token
#
# Let's follow the instructions [here](https://bitly.com/a/sign_in?rd=/a/oauth_apps) to set up an access token for Bitly.
#
# **Note:** You need to create new password using blank existing password if you log in through Google.
#
# We then have the ability to make requests like the following, which provides a shortlink to https://fivethirtyeight.com/:
#
# ```
# https://api-ssl.bitly.com/v3/shorten?access_token=<insert_access_token_here>&longUrl=http%3A%2F%2Ffivethirtyeight.com
# ```
#
# Check out the [documentation](https://dev.bitly.com/) for more information about what you can do with Bitly's APIs.

# %% [markdown]
# ## Handling Keys and Tokens Securely

# %% [markdown]
# Keys and tokens are at least moderately sensitive. Someone who has your key or token could make requests as if they were you, possibly incurring charges or causing you to hit usage limits.
#
# A good way to handle access keys is to store them as **environment variables.** That way, no one can access them without logging into your account on your personal device.

# %% [markdown]
# **Demo.**
#
# **Warning:** These instructions may need to be modified on Windows.

# %% [markdown]
# - The `export` terminal command can be used to assign a value to a variable in your environment. For instance, `export FAKE_ACCESS_KEY=abc` creates an environment variable called "FAKE_ACCESS_KEY" with the value `abc`.

# %% [markdown]
# - The value of an environment variable can be retrieved with `$`. For instance, entering `$FAKE_ACCESS_KEY` in the Terminal will cause it to attempt to run the command `abc`. This command will generate an error, because `abc` is not a known Terminal command. To print the value of "FAKE_ACCESS_KEY", you can run `echo $FAKE_ACCESS_KEY`.

# %% [markdown]
# - Environment variables go away at the end of a session, so running `echo $FAKE_ACCESS_KEY` in a new Terminal window will not work because `FAKE_ACCESS_KEY` is not defined in that window's session.

# %% [markdown]
# - There are special hidden files that run when you start a new Terminal session. For the Mac Terminal, these files include `~/.bashrc` and `~/.bash_profile`. To create an environment variable that is available in all of your future terminal sessions, put the relevant `export` command in one of those files.

# %%
# Access an environment variable with Python 
# /scrub/
print(os.getenv('FAKE_ACCESS_KEY'))
# Out:
# None

# %%
# Insert environment variable into a URL
# This is how you can use a token or key that is stored as an environment
# variable inside a Python program.
# /scrub/
fake_token = os.getenv('FAKE_ACCESS_KEY')
fake_url = f'http://wwww.mywebsite.com/data?access_token={fake_token}'
fake_url
# Out:
# 'http://wwww.mywebsite.com/data?access_token=None'

# %% [markdown]
# **Exercise (8 mins., in pairs, take turns driving so that you both complete the steps on your machine).**

# %% [markdown]
# - Add a line to the file `~/.bash_profile` that creates a variable `MY_ACCESS_KEY_TEST` with the value `asdfghjkl`. Then open a new Terminal window and confirm that this variable has the correct value.

# %% [markdown]
# - In that same Terminal window, enter the command `ipython` to start a Python REPL session. Write Python code to insert MY_ACCESS_KEY_TEST into the fake url 'http://www.coolapi.com/stuff?my_key=<insert MY_ACCESS_KEY_TEST here\>'. Then enter the command `exit` to leave the REPL session.

# %% [markdown]
# - Remove the line you added to `~/.bash_profile` in the first step.

# %% [markdown]
# ## Key Pairs
#
# More secure APIs provide a pair of keys: a public key and a secret key.
#
# The public key is a little like a website username in that you don't need to worry too much about tracking it and keeping it secure. You can often retrieve it by logging into the website associated with the relevant API service.
#
# The secret key is more like a website password: you should be careful to keep track of it and to keep it hidden from others. The website associated with the relevant API service will typically reveal it to you only once, when it is initially created. It is particularly important not to push your secret key to GitHub. Don't EVER include it in a Git commit, because getting it out of your commit history once it is in there is difficult.

# %% [markdown]
# <a name="ind-practice2"></a>
# **Exercise (~30 mins, pair programming)**
#
# Now it's time to start exploring the world of data APIs semi-independently. Go to http://www.pythonforbeginners.com/api/list-of-python-apis or https://github.com/realpython/list-of-python-api-wrappers.
#
# - Choose an API.
# - Find the API documentation and follow the instructions for getting access (e.g. setting up API keys).
#
# This step may push you out of your comfort zone. Don't be afraid to try things. Google and Stack Overflow are your friends. Ask questions when you get stuck. You can't go too far wrong as long as you DON'T PROVIDE CREDIT CARD INFORMATION (unless you know what you are doing) and DON'T SHARE YOUR KEYS/TOKENS and DON'T ADD THEM TO GIT.
#
# - Install the relevant Python client library, if available.
# - Create a Jupyter notebook showing how to extract data from the API and listing a few ways you could use the data it provides.
# - Prepare to share what you found with the rest of the class.
# - **BONUS:** Build a model using data from the API.
